# %% [markdown]
# ## Data Types Assignement

# %% [markdown]
# ### 1. Suppose you invested in Bitcoin at the end of 2020 when Bitcoin gained a lot of value. What would be your money at the end of a week if you had invested $1000 with an average daily increase of 12% ? You can solve the problem using Python.

# %%
capital = 1000
gain = 12
period = 7 
# Gain on day 1
day1 = (capital*gain)/100
new_cap = capital+day1
#Gain on day 2 
day2 = (new_cap*gain)/100
new_cap = new_cap + day2
#Gain on day 3
day3 = (new_cap*gain)/100
new_cap = new_cap + day3
#Gain on day 4
day4 = (new_cap*gain)/100
new_cap = new_cap + day4
#Gain on day5
day5 = (new_cap*gain)/100
new_cap = new_cap+day5
#Gain on day6
day6 = (new_cap*gain)/100
new_cap = new_cap+day6
#Gain on day7
day7 = (new_cap*gain)/100
#total money gained 
total = round(day1+day2+day3+day4+day5+day6+day7, 2)
print(total)
# Out:
# 1210.68

# %% [markdown]
# ### 2. Print the text in quotes with Python. However, you must get the numbers from variables using .format() notation. Because the text is long, you might consider writing in two lines

# %%
print("When we buy bitcoin with {} USD at the beginning of the week, we would earn {} USD at the end of \nthe week, with an average gain of {}%.".format(capital, total, gain))
# Out:
# When we buy bitcoin with 1000 USD at the beginning of the week, we would earn 1210.68 USD at the end of
# the week, with an average gain of 12%.

# %% [markdown]
# ### 3. Get the temperature in Fahrenheit from user and write a code to convert it to Celcius. For conversion, you can use this formula: C = (5/9) * (F - 32)

# %%
print('Enter temperature in Farenheit:')
F = input()
F=int(F)
# Out:
# Enter temperature in Farenheit:
# 104

# %%
#Conversion of Farenheit 
Cent = (5/9)*(F-32)
print('Temperature in Centigrade:', Cent)
# Out:
# Temperature in Centigrade: 40.0

# %% [markdown]
# ### 4. Get a three digit number the from user and calculate the sum of the digits in the integer.

# %%
print('Enter a three digit number')
x = list(input())
# Out:
# Enter a three digit number
# 478

# %%
total = int(x[0]) + int(x[1]) + int(x[2])
print('The sum of digits in the number:', total)
# Out:
# The sum of digits in the number: 19

# %% [markdown]
# ### 5. Write some code to calculate the hypotenuse of a right angled triangle. Get the side lengths from the user.

# %%
print('Enter the first side of the triangle:')
x = int(input())
# Out:
# Enter the first side of the triangle:
# 4

# %%
print('Enter the second side of the triangle:')
y = int(input())
# Out:
# Enter the second side of the triangle:
# 5

# %%
import numpy as np
hyp = np.sqrt(x**2 + y**2)
hyp = round(hyp, 2)
print('The Hypotenuse of the triangle is:', hyp)
# Out:
# The Hypotenuse of the triangle is: 6.4
