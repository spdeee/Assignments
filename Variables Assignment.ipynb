# %% [markdown]
# ## Variables Assignment

# %% [markdown]
# ### 1. Define two variables as x and y. Assign 1 to x and '1' to y. Then check if two variables have the same value and type.

# %%
x = 1
y = '1'
x==y
# Out:
# False

# %%
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# #### x is of type integer and y is of type string, hence x is not equal to y in value and type

# %% [markdown]
# ### 2. Change the type of variable y and make the two variables the same.

# %%
y = int(y)
print(y)
# Out:
# 1

# %%
x == y
# Out:
# True
