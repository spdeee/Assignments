# %% [markdown]
# ## Conditional statements Assignment - Sri Das

# %% [markdown]
# ### 1. Ask the user to enter a number between 10 and 20 (inclusive). If they enter a number within this range, display the message “Thank you”, otherwise display the message “Incorrect answer”.

# %%
print('Enter a number between 10 and 20')
x = input()
x = int(x)
# Out:
# Enter a number between 10 and 20
# 20

# %%
if x>=10 and x<=20:
    print('Thank you')
else:
    print('Incorrect answer')
# Out:
# Thank you

# %% [markdown]
# ### 2.  In this exercise, you will create a program that reads a letter of the alphabet from the user. According to the answer:

# %%
print('Enter an alphabet')
x=input()
# Out:
# Enter an alphabet
# m

# %%
vowels = ['a', 'e', 'i', 'o', 'u']
if x in vowels:
    print('The entered alphabet is a vowel')
elif x == 'y':
    print('The entered aplhabet is sometimes a vowel and sometimes a consonant')
else:
    print('The entered alphabet is a consonant')
# Out:
# The entered alphabet is a consonant
